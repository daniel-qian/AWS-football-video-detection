# %% [markdown]
# # Training-VOC-dataset-AC

# %% [markdown]
# ## Introduction
#
# Object detection is the process of identifying and localizing objects in an image. A typical object detection solution takes in an image as input and provides a bounding box on the image where a object of interest is along with identifying what object the box encapsulates. But before we have this solution, we need to acquire and process a traning dataset, create and setup a training job for the alorithm so that the aglorithm can learn about the dataset and then host the algorithm as an endpoint, to which we can supply the query image.
#
# This notebook is an end-to-end example introducing the Amazon SageMaker Object Detection algorithm. In this demo, we will demonstrate how to train and to host an object detection model on the [Pascal VOC dataset](http://host.robots.ox.ac.uk/pascal/VOC/) using the Single Shot multibox Detector ([SSD](https://arxiv.org/abs/1512.02325)) algorithm. <br>
#
# In doing so, we will also demonstrate how to construct a training dataset using the RecordIO format as this is the format that the training job will consume. We will also demonstrate how to host and validate this trained model. Amazon SageMaker Object Detection also allow training with the image and JSON format, which is illustrated in the [image and JSON Notebook](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/introduction_to_amazon_algorithms/object_detection_pascalvoc_coco/object_detection_image_json_format.ipynb).
#
# The objective is to train an object detection model for number detection using SageMaker Object Detection on the RecordIO format

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# Along with this notebook, we have provided tools that can directly generated the RecordIO files so that you do not need to do addtional work. These tools work with the Pascal datasets lst format, which is also quite the common among most datasets. If your data are stored in a different format or the annotation of your data is in a different format than the Pascal VOC dataset, you can also create the RecordIO by first generating the .lst file and then using the im2rec tool provided by MXNet. To make things clear, we will explain the definition of a .lst file so that you can prepare it in your own way. The following example is the first three lines of the .lst file we just generated for the Pascal VOC dataset.

# %%
pip install mxnet
# Out:
# Requirement already satisfied: mxnet in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (1.8.0.post0)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from mxnet) (0.8.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from mxnet) (2.25.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from mxnet) (1.19.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/chainer_p36/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/chainer_p36/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Convert data into RecordIO
# [RecordIO](https://mxnet.incubator.apache.org/architecture/note_data_loading.html) is a highly efficient binary data format from [MXNet](https://mxnet.incubator.apache.org/) that makes it easy and simple to prepare the dataset and transfer to the instance that will run the training job. To generate a RecordIO file, we will use the tools from MXNet. The provided tools will first generate a list file and then use the [im2rec tool](https://github.com/apache/incubator-mxnet/blob/master/tools/im2rec.py) to create the [RecordIO](https://mxnet.incubator.apache.org/architecture/note_data_loading.html) file. More details on how to generate RecordIO file for object detection task, see the [MXNet example](https://github.com/apache/incubator-mxnet/tree/master/example/ssd).

# %%
# %%time

# AC train split
# !python tools/prepare_dataset.py --dataset pascal --year 2007,2012 --set train --target VOCdevkit/train.lst

# AC val split
# !python tools/prepare_dataset.py --dataset pascal --year 2007,2012 --set val --target VOCdevkit/val.lst --no-shuffle
# Out:
# saving list to disk...
# List file VOCdevkit/train.lst generated...
# Creating .rec file from /home/ec2-user/SageMaker/VOCdevkit/train.lst in /home/ec2-user/SageMaker/VOCdevkit
# time: 0.0034677982330322266  count: 0
# time: 0.05230855941772461  count: 100
# time: 0.05035090446472168  count: 200
# time: 0.019797086715698242  count: 300
# time: 0.03390192985534668  count: 400
# time: 0.03158736228942871  count: 500
# time: 0.013025522232055664  count: 600
# total count:
# 696
# Record file VOCdevkit/train.rec generated...
# saving list to disk...
# List file VOCdevkit/val.lst generated...
# Creating .rec file from /home/ec2-user/SageMaker/VOCdevkit/val.lst in /home/ec2-user/SageMaker/VOCdevkit
# time: 0.004147529602050781  count: 0
# time: 0.04494142532348633  count: 100
# time: 0.02583622932434082  count: 200
# time: 0.02292180061340332  count: 300
# time: 0.031751155853271484  count: 400
# total count:
# 465
# Record file VOCdevkit/val.rec generated...
# CPU times: user 83 ms, sys: 25.1 ms, total: 108 ms
# Wall time: 5.31 s

# %%
# set training samples number to the train datas count in the output log above 
training_sample_no = 696

# %% [markdown]
# ### Understanding RecodIO format

# %% [markdown]
# Along with this notebook, we have provided tools that can directly generated the RecordIO files so that you do not need to do addtional work. These tools work with the Pascal datasets lst format, which is also quite the common among most datasets. If your data are stored in a different format or the annotation of your data is in a different format than the Pascal VOC dataset, you can also create the RecordIO by first generating the .lst file and then using the im2rec tool provided by MXNet. To make things clear, we will explain the definition of a .lst file so that you can prepare it in your own way. The following example is the first three lines of the .lst file we just generated for the Pascal VOC dataset.

# %%
# !head -n 3 VOCdevkit/train.lst > example.lst
f = open('example.lst','r')
lst_content = f.read()
print(lst_content)
# Out:
# 0	2	5	2.0000	0.3600	0.1667	0.6800	0.3333	VOC2007/JPEGImages/2430_2_orginal.jpg
# 1	2	5	9.0000	0.2564	0.2289	0.4359	0.3976	VOC2007/JPEGImages/8964_21_orginal.jpg
# 2	2	5	9.0000	0.2778	0.2824	0.4722	0.4235	VOC2007/JPEGImages/91_21_orginal.jpg

# %% [markdown]
# As can be seen that each line in the .lst file represents the annotations for a image. A .lst file is a tab-delimited file with multiple columns. The rows of the file are annotations of the of image files. The first column specifies a unique image index. The second column specifies the header size of the current row. In the above example .lst file, 2 from the second column means the second and third columns are header information, which will not be considered as label and bounding box information of the image specified by the current row.
#
# The third column specifies the label width of a single object. In the first row of above sample .lst file, 5 from the third row means each object within an image will have 5 numbers to describe its label information, including class index, and bounding box coordinates. If there are multiple objects within one image, all the label information should be listed in one line. The annotation information for each object is represented as [class_index, xmin, ymin, xmax, ymax].
#
# The classes should be labeled with successive numbers and start with 0. The bounding box coordinates are ratios of its top-left (xmin, ymin) and bottom-right (xmax, ymax) corner indices to the overall image size. Note that the top-left corner of the entire image is the origin (0, 0). The last column specifies the relative path of the image file.

# %% [markdown]
# ## Setup
#
# To train the Object Detection algorithm on Amazon SageMaker, we need to setup and authenticate the use of AWS services. To begin with we need an AWS account role with SageMaker access. This role is used to give SageMaker access to your data in S3 will automatically be obtained from the role used to start the notebook.

# %%
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
sess = sagemaker.Session()
# Out:
# arn:aws:iam::874960312361:role/service-role/AmazonSageMaker-ExecutionRole-20210809T140402
# CPU times: user 520 ms, sys: 113 ms, total: 633 ms
# Wall time: 4.73 s

# %% [markdown]
# We also need the S3 bucket that you want to use for training and to store the tranied model artifacts. In this notebook, we require a custom bucket that exists so as to keep the naming clean. You can end up using a default bucket that SageMaker comes with as well.

# %%
training_bucket = 'number-detection-pascal-0816' # custom bucket name.
# bucket = sess.default_bucket()
training_prefix = 'NumberDetection0829'

# %% [markdown]
# Lastly, we need the Amazon SageMaker Object Detection docker image, which is static and need not be changed.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

training_image = get_image_uri(sess.boto_region_name, 'object-detection', repo_version="latest")
print (training_image)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 644912444149.dkr.ecr.eu-west-2.amazonaws.com/object-detection:1

# %% [markdown]
# ### Upload data to S3

# %% [markdown]
# Upload the data to the S3 bucket. We do this in multiple channels. Channels are simply directories in the bucket that differentiate between training and validation data. Let us simply call these directories train and validation.

# %%
# %%time

# Upload the RecordIO files to train and validation channels
train_channel = training_prefix + '/train'
validation_channel = training_prefix + '/validation'

sess.upload_data(path='VOCdevkit/train.rec', bucket=training_bucket, key_prefix=train_channel)
sess.upload_data(path='VOCdevkit/val.rec', bucket=training_bucket, key_prefix=validation_channel)

s3_train_data = 's3://{}/{}'.format(training_bucket, train_channel)
s3_validation_data = 's3://{}/{}'.format(training_bucket, validation_channel)

print(s3_train_data)
print(s3_validation_data)
# Out:
# s3://number-detection-pascal-0816/NumberDetection0829/train
# s3://number-detection-pascal-0816/NumberDetection0829/validation
# CPU times: user 90.6 ms, sys: 18.9 ms, total: 109 ms
# Wall time: 619 ms

# %% [markdown]
# Next we need to setup an output location at S3, where the model artifact will be dumped. These artifacts are also the output of the algorithm's traning job.

# %%
s3_number_output_location = 's3://{}/{}/output'.format(training_bucket, training_prefix)

print(s3_number_output_location)
# Out:
# s3://number-detection-pascal-0816/NumberDetection0829/output

# %% [markdown]
# ### Tuning Hyperparameter

# %% [markdown]
# Normally, in AWS machine learning, tuning hyperparameters means runing parallel training jobs at the same time, then select the bset performing training job from all tuning outputs. However, to save time from waiting for multiples training jobs to complete, we will create an seperate esitimator just for a short tuning epochs to get the best performimg hyperparameters' value and use them on just one training job.

# %% [markdown]
# Set up the estimator for tuning, with the following configuration:

# %%
sess = sagemaker.Session()

# Esitimator configuration
no_tune_model = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.p3.2xlarge',
                                         train_volume_size = 50,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_number_output_location,
                                         sagemaker_session=sess)

# Static Hyperparameters
no_tune_model.set_hyperparameters(base_network='resnet-50',
                             use_pretrained_model=1,
                             num_classes=10,
                             epochs=10,
                             image_shape=300,
                             label_width=350,
                             num_training_samples=training_sample_no)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_run has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_volume_size has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# Next, we set up the tuning job with the following configuration:
#
# - the hyperparameters that SageMaker Automatic Model Tuning will tune: learning_rate, mini_batch_size
# - the maximum number of training jobs it will run to optimize the objective metric: 5
# - the number of parallel training jobs that will run in the tuning job: 2
# - the objective metric that Automatic Model Tuning will use: validation:accuracy

# %%
from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner,
)

# tuner will tune hyperparameter between these range
hyperparameter_ranges = {
    "learning_rate": ContinuousParameter(1e-6, 0.05),
    "mini_batch_size": IntegerParameter(8,64),
}

# tuner will compare results using mAP value
objective_metric_name = "validation:mAP"

tuner = HyperparameterTuner(
    no_tune_model,
    objective_metric_name,
    hyperparameter_ranges,
    objective_type="Maximize",
    max_jobs=5,
    max_parallel_jobs=2,
)

# %% [markdown]
# Launch hyperparameter tuning job

# %%
tuner.fit({"train": s3_train_data, "validation": s3_validation_data}, include_cls_metadata=False)
# Out:
# ...................................................................................................................................................................................................!

# %% [markdown]
# Once the tuning job finishes, we can bring in a table of metrics.

# %%
tuning_job_name = tuner._current_job_name

tuner_parent_metrics = sagemaker.HyperparameterTuningJobAnalytics(tuning_job_name)
if not tuner_parent_metrics.dataframe().empty:
    df_parent = tuner_parent_metrics.dataframe().sort_values(
        ["FinalObjectiveValue"], ascending=False
    )

df_parent
# Out:
#    learning_rate  mini_batch_size  momentum optimizer  weight_decay  \
# 0       0.000109             37.0  0.990000  adadelta      0.986785
# 2       0.000156             52.0  0.988546  adadelta      0.957040
# 1       0.000002             63.0  0.857526  adadelta      0.983342
# 3       0.000788             63.0  0.821025  adadelta      0.899333
# 4       0.006980             49.0  0.734552       sgd      0.942915
#
#                              TrainingJobName TrainingJobStatus  \
# 0  object-detection-210829-0823-005-4e54bb72         Completed
# 2  object-detection-210829-0823-003-045a592a         Completed
# 1  object-detection-210829-0823-004-e5ef522c         Completed
# 3  object-detection-210829-0823-002-640817a7         Completed
# 4  object-detection-210829-0823-001-50e6c93a         Completed
#
#    FinalObjectiveValue         TrainingStartTime           TrainingEndTime  \
# 0             0.160799 2021-08-29 08:38:56+00:00 2021-08-29 08:42:22+00:00
# 2             0.017044 2021-08-29 08:33:53+00:00 2021-08-29 08:36:41+00:00
# 1             0.004826 2021-08-29 08:33:46+00:00 2021-08-29 08:36:23+00:00
# 3             0.004255 2021-08-29 08:26:26+00:00 2021-08-29 08:29:54+00:00
# 4             0.000027 2021-08-29 08:26:33+00:00 2021-08-29 08:29:54+00:00
#
#    TrainingElapsedTimeSeconds
# 0                       206.0
# 2                       168.0
# 1                       157.0
# 3                       208.0
# 4                       201.0

# %% [markdown]
# ### Training

# %% [markdown]
# Now that we are done with all the setup that is needed, we are ready to train our object detector. To begin, let us create a sageMaker.estimator.Estimator object. This estimator will launch the training job.

# %%
# estimator configuration for training
no_od_model = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.p3.2xlarge',
                                         train_volume_size = 50,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_number_output_location,
                                         sagemaker_session=sess)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_run has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_volume_size has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# The object detection algorithm at its core is the Single-Shot Multi-Box detection algorithm (SSD). This algorithm uses a base_network, which is typically a VGG or a ResNet. The Amazon SageMaker object detection algorithm supports VGG-16 and ResNet-50 now. It also has a lot of options for hyperparameters that help configure the training job. The next step in our training, is to setup these hyperparameters and data channels for training the model.
#
# We will apply the hyperparameters among the best-performed tuning jobs, which are leanring_rate and mini_batch_size, as showed in the table above

# %%
# use the best-performed parameters in the tuning session
no_od_model.set_hyperparameters(base_network='resnet-50',
                             use_pretrained_model=1,
                             num_classes=10,
                             mini_batch_size=37,
                             epochs=100,
                             learning_rate=0.000109,
                             optimizer='adadelta',
                             image_shape=300,
                             label_width=350,
                             num_training_samples=training_sample_no)

# %% [markdown]
# Now that the hyperparameters are setup, let us prepare the handshake between our data channels and the algorithm. To do this, we need to create the sagemaker.session.s3_input objects from our data channels. These objects are then put in a simple dictionary, which the algorithm consumes.

# %%
train_data = sagemaker.session.s3_input(s3_train_data, distribution='FullyReplicated', 
                        content_type='application/x-recordio', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input(s3_validation_data, distribution='FullyReplicated', 
                             content_type='application/x-recordio', s3_data_type='S3Prefix')
data_channels = {'train': train_data, 'validation': validation_data}
print(s3_train_data)
print(s3_validation_data)
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# s3://number-detection-pascal-0816/NumberDetection0829/train
# s3://number-detection-pascal-0816/NumberDetection0829/validation

# %% [markdown]
# We have our Estimator object, we have set the hyperparameters for this object and we have our data channels linked with the algorithm. The only remaining thing to do is to train the algorithm. The following command will train the algorithm. Training the algorithm involves a few steps. Firstly, the instances that we requested while creating the Estimator classes are provisioned and are setup with the appropriate libraries. Then, the data from our channels are downloaded into the instance. Once this is done, the training job begins. The provisioning and data downloading will take time, depending on the size of the data. Therefore it might be a few minutes before we start getting data logs for our training jobs. The data logs will also print out Mean Average Precision (mAP) on the validation data, among other losses, for every run of the dataset once or one epoch. This metric is a proxy for the quality of the algorithm.
#
# Once the job has finished a "Job complete" message will be printed. The trained model can be found in the S3 bucket that was setup as output_path in the estimator.

# %%
no_od_model.fit(inputs=data_channels, logs=True)
# Out:
# 2021-08-29 09:01:26 Starting - Starting the training job...
# 2021-08-29 09:01:49 Starting - Launching requested ML instancesProfilerReport-1630227686: InProgress
# ......
# 2021-08-29 09:02:49 Starting - Preparing the instances for training.........
# 2021-08-29 09:04:22 Downloading - Downloading input data
# 2021-08-29 09:04:22 Training - Downloading the training image...[08/29/2021 09:07:28 INFO 139876594259776] #quality_metric: host=algo-1, epoch=11, batch=19 train cross_entropy <loss>=(1.068715231529945)
# [08/29/2021 09:07:28 INFO 139876594259776] #quality_metric: host=algo-1, epoch=11, batch=19 train smooth_l1 <loss>=(0.45227343663980746)
# [08/29/2021 09:07:28 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:07:28 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:07:32 INFO 139876594259776] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.33395500528406874)
# [08/29/2021 09:07:32 INFO 139876594259776] Updating the best model with validation-mAP=0.33395500528406874
# [08/29/2021 09:07:32 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:07:32 INFO 139876594259776] #progress_metric: host=algo-1, completed 12.0 % of epochs
# #metrics {"StartTime": 1630228042.713971, "EndTime": 1630228052.9528182, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:07:38 INFO 139876594259776] #quality_metric: host=algo-1, epoch=12, batch=19 train cross_entropy <loss>=(1.045510904395205)
# [08/29/2021 09:07:38 INFO 139876594259776] #quality_metric: host=algo-1, epoch=12, batch=19 train smooth_l1 <loss>=(0.4420664064737166)
# [08/29/2021 09:07:38 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:07:38 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:07:42 INFO 139876594259776] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.4008524077129224)
# [08/29/2021 09:07:42 INFO 139876594259776] Updating the best model with validation-mAP=0.4008524077129224
# [08/29/2021 09:07:42 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:07:42 INFO 139876594259776] #progress_metric: host=algo-1, completed 13.0 % of epochs
# #metrics {"StartTime": 1630228052.9531124, "EndTime": 1630228062.7175837, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:07:48 INFO 139876594259776] #quality_metric: host=algo-1, epoch=13, batch=19 train cross_entropy <loss>=(1.0412156390328693)
# [08/29/2021 09:07:48 INFO 139876594259776] #quality_metric: host=algo-1, epoch=13, batch=19 train smooth_l1 <loss>=(0.43015304304595686)
# [08/29/2021 09:07:48 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:07:48 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:07:52 INFO 139876594259776] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.43288179659483894)
# [08/29/2021 09:07:52 INFO 139876594259776] Updating the best model with validation-mAP=0.43288179659483894
# [08/29/2021 09:07:53 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:07:53 INFO 139876594259776] #progress_metric: host=algo-1, completed 14.0 % of epochs
# #metrics {"StartTime": 1630228062.717821, "EndTime": 1630228073.052708, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:07:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=14, batch=19 train cross_entropy <loss>=(1.009812708614635)
# [08/29/2021 09:07:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=14, batch=19 train smooth_l1 <loss>=(0.40045140714061506)
# [08/29/2021 09:07:58 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:07:59 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:03 INFO 139876594259776] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.469634572956954)
# [08/29/2021 09:08:03 INFO 139876594259776] Updating the best model with validation-mAP=0.469634572956954
# [08/29/2021 09:08:03 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:08:03 INFO 139876594259776] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1630228073.0530736, "EndTime": 1630228083.762469, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:08:09 INFO 139876594259776] #quality_metric: host=algo-1, epoch=15, batch=18 train cross_entropy <loss>=(1.0253164674160207)
# [08/29/2021 09:08:09 INFO 139876594259776] #quality_metric: host=algo-1, epoch=15, batch=18 train smooth_l1 <loss>=(0.39366206828357836)
# [08/29/2021 09:08:09 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:09 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:13 INFO 139876594259776] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.4804690748038182)
# [08/29/2021 09:08:13 INFO 139876594259776] Updating the best model with validation-mAP=0.4804690748038182
# [08/29/2021 09:08:13 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:08:13 INFO 139876594259776] #progress_metric: host=algo-1, completed 16.0 % of epochs
# #metrics {"StartTime": 1630228083.7630267, "EndTime": 1630228093.5593169, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 15, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:08:19 INFO 139876594259776] #quality_metric: host=algo-1, epoch=16, batch=19 train cross_entropy <loss>=(0.9906130239997112)
# [08/29/2021 09:08:19 INFO 139876594259776] #quality_metric: host=algo-1, epoch=16, batch=19 train smooth_l1 <loss>=(0.36488096478959203)
# [08/29/2021 09:08:19 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:19 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:23 INFO 139876594259776] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.5133099965040084)
# [08/29/2021 09:08:23 INFO 139876594259776] Updating the best model with validation-mAP=0.5133099965040084
# [08/29/2021 09:08:23 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:08:23 INFO 139876594259776] #progress_metric: host=algo-1, completed 17.0 % of epochs
# #metrics {"StartTime": 1630228093.559628, "EndTime": 1630228103.943801, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 16, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:08:29 INFO 139876594259776] #quality_metric: host=algo-1, epoch=17, batch=19 train cross_entropy <loss>=(0.9891486854910952)
# [08/29/2021 09:08:29 INFO 139876594259776] #quality_metric: host=algo-1, epoch=17, batch=19 train smooth_l1 <loss>=(0.36443304954587347)
# [08/29/2021 09:08:29 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:29 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:33 INFO 139876594259776] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.5542640315514096)
# [08/29/2021 09:08:33 INFO 139876594259776] Updating the best model with validation-mAP=0.5542640315514096
# [08/29/2021 09:08:33 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:08:33 INFO 139876594259776] #progress_metric: host=algo-1, completed 18.0 % of epochs
# #metrics {"StartTime": 1630228103.9441192, "EndTime": 1630228113.7084615, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 17, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:08:39 INFO 139876594259776] #quality_metric: host=algo-1, epoch=18, batch=19 train cross_entropy <loss>=(0.9597011901015053)
# [08/29/2021 09:08:39 INFO 139876594259776] #quality_metric: host=algo-1, epoch=18, batch=19 train smooth_l1 <loss>=(0.35019592820264384)
# [08/29/2021 09:08:39 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:39 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:43 INFO 139876594259776] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.5466831708813318)
# [08/29/2021 09:08:43 INFO 139876594259776] #progress_metric: host=algo-1, completed 19.0 % of epochs
# #metrics {"StartTime": 1630228113.7091763, "EndTime": 1630228123.7785976, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 18, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:08:49 INFO 139876594259776] #quality_metric: host=algo-1, epoch=19, batch=19 train cross_entropy <loss>=(0.9302225658927454)
# [08/29/2021 09:08:49 INFO 139876594259776] #quality_metric: host=algo-1, epoch=19, batch=19 train smooth_l1 <loss>=(0.33448846351469175)
# [08/29/2021 09:08:49 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:49 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:08:53 INFO 139876594259776] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.6197293297947665)
# [08/29/2021 09:08:53 INFO 139876594259776] Updating the best model with validation-mAP=0.6197293297947665
# [08/29/2021 09:08:53 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:08:53 INFO 139876594259776] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1630228123.7788382, "EndTime": 1630228133.5473063, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:08:59 INFO 139876594259776] #quality_metric: host=algo-1, epoch=20, batch=19 train cross_entropy <loss>=(0.9176306110027369)
# [08/29/2021 09:08:59 INFO 139876594259776] #quality_metric: host=algo-1, epoch=20, batch=19 train smooth_l1 <loss>=(0.3254995174936914)
# [08/29/2021 09:08:59 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:08:59 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:09:03 INFO 139876594259776] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.6201435408645983)
# [08/29/2021 09:09:03 INFO 139876594259776] Updating the best model with validation-mAP=0.6201435408645983
# [08/29/2021 09:09:03 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:09:03 INFO 139876594259776] #progress_metric: host=algo-1, completed 21.0 % of epochs
# #metrics {"StartTime": 1630228133.5475516, "EndTime": 1630228143.6315095, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:09:09 INFO 139876594259776] #quality_metric: host=algo-1, epoch=21, batch=18 train cross_entropy <loss>=(0.8983448772683107)
# [08/29/2021 09:09:09 INFO 139876594259776] #quality_metric: host=algo-1, epoch=21, batch=18 train smooth_l1 <loss>=(0.3107869194870727)
# [08/29/2021 09:09:09 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:09:09 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:09:13 INFO 139876594259776] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.6465709130329604)
# [08/29/2021 09:09:13 INFO 139876594259776] Updating the best model with validation-mAP=0.6465709130329604
# [08/29/2021 09:09:13 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:09:13 INFO 139876594259776] #progress_metric: host=algo-1, completed 22.0 % of epochs
# #metrics {"StartTime": 1630228143.6322534, "EndTime": 1630228153.9047267, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 21, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:09:29 INFO 139876594259776] #quality_metric: host=algo-1, epoch=23, batch=19 train cross_entropy <loss>=(0.8912197573059374)
# [08/29/2021 09:09:29 INFO 139876594259776] #quality_metric: host=algo-1, epoch=23, batch=19 train smooth_l1 <loss>=(0.3174312518480606)
# [08/29/2021 09:09:29 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:09:29 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:09:33 INFO 139876594259776] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.6755727139212019)
# [08/29/2021 09:09:33 INFO 139876594259776] Updating the best model with validation-mAP=0.6755727139212019
# [08/29/2021 09:09:33 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:09:33 INFO 139876594259776] #progress_metric: host=algo-1, completed 24.0 % of epochs
# #metrics {"StartTime": 1630228163.756012, "EndTime": 1630228173.7520223, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 23, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:09:39 INFO 139876594259776] #quality_metric: host=algo-1, epoch=24, batch=19 train cross_entropy <loss>=(0.8674934038281336)
# [08/29/2021 09:09:39 INFO 139876594259776] #quality_metric: host=algo-1, epoch=24, batch=19 train smooth_l1 <loss>=(0.29834555321444306)
# [08/29/2021 09:09:39 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:09:39 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:09:43 INFO 139876594259776] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.7018472935599996)
# [08/29/2021 09:09:43 INFO 139876594259776] Updating the best model with validation-mAP=0.7018472935599996
# [08/29/2021 09:09:43 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:09:43 INFO 139876594259776] #progress_metric: host=algo-1, completed 25.0 % of epochs
# #metrics {"StartTime": 1630228173.7523267, "EndTime": 1630228183.3843744, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 24, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:09:49 INFO 139876594259776] #quality_metric: host=algo-1, epoch=25, batch=19 train cross_entropy <loss>=(0.8666985382093422)
# [08/29/2021 09:09:49 INFO 139876594259776] #quality_metric: host=algo-1, epoch=25, batch=19 train smooth_l1 <loss>=(0.30529299020037465)
# [08/29/2021 09:09:49 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:09:49 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:09:53 INFO 139876594259776] #quality_metric: host=algo-1, epoch=25, validation mAP <score>=(0.7355404397764047)
# [08/29/2021 09:09:53 INFO 139876594259776] Updating the best model with validation-mAP=0.7355404397764047
# [08/29/2021 09:09:53 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:09:53 INFO 139876594259776] #progress_metric: host=algo-1, completed 26.0 % of epochs
# #metrics {"StartTime": 1630228183.3846176, "EndTime": 1630228193.4338837, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 25, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:09:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=26, batch=18 train cross_entropy <loss>=(0.8533247261716609)
# [08/29/2021 09:09:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=26, batch=18 train smooth_l1 <loss>=(0.28877613251669365)
# [08/29/2021 09:09:58 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:09:59 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:02 INFO 139876594259776] #quality_metric: host=algo-1, epoch=26, validation mAP <score>=(0.7144655782716142)
# [08/29/2021 09:10:02 INFO 139876594259776] #progress_metric: host=algo-1, completed 27.0 % of epochs
# #metrics {"StartTime": 1630228193.4341402, "EndTime": 1630228202.5024707, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 26, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 27.0, "count": 1, "min": 27, "max": 27}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:10:08 INFO 139876594259776] #quality_metric: host=algo-1, epoch=27, batch=19 train cross_entropy <loss>=(0.8261474864219076)
# [08/29/2021 09:10:08 INFO 139876594259776] #quality_metric: host=algo-1, epoch=27, batch=19 train smooth_l1 <loss>=(0.28594252839217854)
# [08/29/2021 09:10:08 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:08 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:12 INFO 139876594259776] #quality_metric: host=algo-1, epoch=27, validation mAP <score>=(0.7586111208669759)
# [08/29/2021 09:10:12 INFO 139876594259776] Updating the best model with validation-mAP=0.7586111208669759
# [08/29/2021 09:10:12 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:10:12 INFO 139876594259776] #progress_metric: host=algo-1, completed 28.0 % of epochs
# #metrics {"StartTime": 1630228202.5027134, "EndTime": 1630228212.7564578, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 27, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 28.0, "count": 1, "min": 28, "max": 28}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:10:18 INFO 139876594259776] #quality_metric: host=algo-1, epoch=28, batch=19 train cross_entropy <loss>=(0.8180135941336059)
# [08/29/2021 09:10:18 INFO 139876594259776] #quality_metric: host=algo-1, epoch=28, batch=19 train smooth_l1 <loss>=(0.2818850394925262)
# [08/29/2021 09:10:18 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:18 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:22 INFO 139876594259776] #quality_metric: host=algo-1, epoch=28, validation mAP <score>=(0.7714293653709008)
# [08/29/2021 09:10:22 INFO 139876594259776] Updating the best model with validation-mAP=0.7714293653709008
# [08/29/2021 09:10:22 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:10:22 INFO 139876594259776] #progress_metric: host=algo-1, completed 29.0 % of epochs
# #metrics {"StartTime": 1630228212.7567995, "EndTime": 1630228222.6492672, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 28, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 29.0, "count": 1, "min": 29, "max": 29}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:10:28 INFO 139876594259776] #quality_metric: host=algo-1, epoch=29, batch=19 train cross_entropy <loss>=(0.7971301642388778)
# [08/29/2021 09:10:28 INFO 139876594259776] #quality_metric: host=algo-1, epoch=29, batch=19 train smooth_l1 <loss>=(0.28900632144814836)
# [08/29/2021 09:10:28 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:28 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:31 INFO 139876594259776] #quality_metric: host=algo-1, epoch=29, validation mAP <score>=(0.7832640599644469)
# [08/29/2021 09:10:31 INFO 139876594259776] Updating the best model with validation-mAP=0.7832640599644469
# [08/29/2021 09:10:31 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:10:31 INFO 139876594259776] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1630228222.6495142, "EndTime": 1630228231.7223356, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 29, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 30.0, "count": 1, "min": 30, "max": 30}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:10:37 INFO 139876594259776] #quality_metric: host=algo-1, epoch=30, batch=19 train cross_entropy <loss>=(0.8071640722666837)
# [08/29/2021 09:10:37 INFO 139876594259776] #quality_metric: host=algo-1, epoch=30, batch=19 train smooth_l1 <loss>=(0.27315668054797393)
# [08/29/2021 09:10:37 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:37 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:41 INFO 139876594259776] #quality_metric: host=algo-1, epoch=30, validation mAP <score>=(0.7817188510308547)
# [08/29/2021 09:10:41 INFO 139876594259776] #progress_metric: host=algo-1, completed 31.0 % of epochs
# #metrics {"StartTime": 1630228231.7226634, "EndTime": 1630228241.101256, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 30, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:10:46 INFO 139876594259776] #quality_metric: host=algo-1, epoch=31, batch=18 train cross_entropy <loss>=(0.7762386674174074)
# [08/29/2021 09:10:46 INFO 139876594259776] #quality_metric: host=algo-1, epoch=31, batch=18 train smooth_l1 <loss>=(0.26318060739195415)
# [08/29/2021 09:10:46 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:46 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:49 INFO 139876594259776] #quality_metric: host=algo-1, epoch=31, validation mAP <score>=(0.746258062546784)
# [08/29/2021 09:10:49 INFO 139876594259776] #progress_metric: host=algo-1, completed 32.0 % of epochs
# #metrics {"StartTime": 1630228241.101506, "EndTime": 1630228249.8851557, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 31, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 32.0, "count": 1, "min": 32, "max": 32}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:10:55 INFO 139876594259776] #quality_metric: host=algo-1, epoch=32, batch=19 train cross_entropy <loss>=(0.7754220525941043)
# [08/29/2021 09:10:55 INFO 139876594259776] #quality_metric: host=algo-1, epoch=32, batch=19 train smooth_l1 <loss>=(0.2863204416133235)
# [08/29/2021 09:10:55 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:10:55 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:10:59 INFO 139876594259776] #quality_metric: host=algo-1, epoch=32, validation mAP <score>=(0.7855721654198972)
# [08/29/2021 09:10:59 INFO 139876594259776] Updating the best model with validation-mAP=0.7855721654198972
# [08/29/2021 09:10:59 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:10:59 INFO 139876594259776] #progress_metric: host=algo-1, completed 33.0 % of epochs
# #metrics {"StartTime": 1630228249.885448, "EndTime": 1630228259.3884835, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 32, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 33.0, "count": 1, "min": 33, "max": 33}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:11:05 INFO 139876594259776] #quality_metric: host=algo-1, epoch=33, batch=19 train cross_entropy <loss>=(0.776011242680945)
# [08/29/2021 09:11:05 INFO 139876594259776] #quality_metric: host=algo-1, epoch=33, batch=19 train smooth_l1 <loss>=(0.2678452441736728)
# [08/29/2021 09:11:05 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:05 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:11:08 INFO 139876594259776] #quality_metric: host=algo-1, epoch=33, validation mAP <score>=(0.8015579706886415)
# [08/29/2021 09:11:08 INFO 139876594259776] Updating the best model with validation-mAP=0.8015579706886415
# [08/29/2021 09:11:08 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:11:08 INFO 139876594259776] #progress_metric: host=algo-1, completed 34.0 % of epochs
# #metrics {"StartTime": 1630228259.3888118, "EndTime": 1630228268.8768466, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 33, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 34.0, "count": 1, "min": 34, "max": 34}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:11:14 INFO 139876594259776] #quality_metric: host=algo-1, epoch=34, batch=19 train cross_entropy <loss>=(0.748676065079877)
# [08/29/2021 09:11:14 INFO 139876594259776] #quality_metric: host=algo-1, epoch=34, batch=19 train smooth_l1 <loss>=(0.2682091073094936)
# [08/29/2021 09:11:14 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:14 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:11:17 INFO 139876594259776] #quality_metric: host=algo-1, epoch=34, validation mAP <score>=(0.8080552218051814)
# [08/29/2021 09:11:17 INFO 139876594259776] Updating the best model with validation-mAP=0.8080552218051814
# [08/29/2021 09:11:18 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:11:18 INFO 139876594259776] #progress_metric: host=algo-1, completed 35.0 % of epochs
# #metrics {"StartTime": 1630228268.8770869, "EndTime": 1630228278.0808175, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 34, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 35.0, "count": 1, "min": 35, "max": 35}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:11:31 INFO 139876594259776] #quality_metric: host=algo-1, epoch=36, batch=18 train cross_entropy <loss>=(0.7342199819035048)
# [08/29/2021 09:11:31 INFO 139876594259776] #quality_metric: host=algo-1, epoch=36, batch=18 train smooth_l1 <loss>=(0.25942959286370426)
# [08/29/2021 09:11:31 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:32 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:11:34 INFO 139876594259776] #quality_metric: host=algo-1, epoch=36, validation mAP <score>=(0.8272840933547707)
# [08/29/2021 09:11:34 INFO 139876594259776] Updating the best model with validation-mAP=0.8272840933547707
# [08/29/2021 09:11:35 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:11:35 INFO 139876594259776] #progress_metric: host=algo-1, completed 37.0 % of epochs
# #metrics {"StartTime": 1630228286.58614, "EndTime": 1630228295.14691, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 36, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 37.0, "count": 1, "min": 37, "max": 37}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:11:41 INFO 139876594259776] #quality_metric: host=algo-1, epoch=37, batch=19 train cross_entropy <loss>=(0.7103749752651084)
# [08/29/2021 09:11:41 INFO 139876594259776] #quality_metric: host=algo-1, epoch=37, batch=19 train smooth_l1 <loss>=(0.25922506913738563)
# [08/29/2021 09:11:41 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:41 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:11:44 INFO 139876594259776] #quality_metric: host=algo-1, epoch=37, validation mAP <score>=(0.8391656318956173)
# [08/29/2021 09:11:44 INFO 139876594259776] Updating the best model with validation-mAP=0.8391656318956173
# [08/29/2021 09:11:44 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:11:44 INFO 139876594259776] #progress_metric: host=algo-1, completed 38.0 % of epochs
# #metrics {"StartTime": 1630228295.147176, "EndTime": 1630228304.529245, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 37, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 38.0, "count": 1, "min": 38, "max": 38}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:11:50 INFO 139876594259776] #quality_metric: host=algo-1, epoch=38, batch=19 train cross_entropy <loss>=(0.7124345023056556)
# [08/29/2021 09:11:50 INFO 139876594259776] #quality_metric: host=algo-1, epoch=38, batch=19 train smooth_l1 <loss>=(0.2491602248158948)
# [08/29/2021 09:11:50 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:50 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:11:52 INFO 139876594259776] #quality_metric: host=algo-1, epoch=38, validation mAP <score>=(0.8395212364999278)
# [08/29/2021 09:11:52 INFO 139876594259776] Updating the best model with validation-mAP=0.8395212364999278
# [08/29/2021 09:11:52 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:11:52 INFO 139876594259776] #progress_metric: host=algo-1, completed 39.0 % of epochs
# #metrics {"StartTime": 1630228304.5295227, "EndTime": 1630228312.9550107, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 38, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 39.0, "count": 1, "min": 39, "max": 39}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:11:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=39, batch=19 train cross_entropy <loss>=(0.727266616000924)
# [08/29/2021 09:11:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=39, batch=19 train smooth_l1 <loss>=(0.26163631480227234)
# [08/29/2021 09:11:58 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:11:58 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:12:01 INFO 139876594259776] #quality_metric: host=algo-1, epoch=39, validation mAP <score>=(0.8389812936748792)
# [08/29/2021 09:12:01 INFO 139876594259776] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1630228312.9553878, "EndTime": 1630228321.1366432, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 39, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 40.0, "count": 1, "min": 40, "max": 40}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:12:07 INFO 139876594259776] #quality_metric: host=algo-1, epoch=40, batch=19 train cross_entropy <loss>=(0.718045370451991)
# [08/29/2021 09:12:07 INFO 139876594259776] #quality_metric: host=algo-1, epoch=40, batch=19 train smooth_l1 <loss>=(0.25071530399355224)
# [08/29/2021 09:12:07 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:12:07 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:12:09 INFO 139876594259776] #quality_metric: host=algo-1, epoch=40, validation mAP <score>=(0.8613838780016885)
# [08/29/2021 09:12:09 INFO 139876594259776] Updating the best model with validation-mAP=0.8613838780016885
# [08/29/2021 09:12:09 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:12:09 INFO 139876594259776] #progress_metric: host=algo-1, completed 41.0 % of epochs
# #metrics {"StartTime": 1630228321.1369863, "EndTime": 1630228329.931883, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 40, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 41.0, "count": 1, "min": 41, "max": 41}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:12:15 INFO 139876594259776] #quality_metric: host=algo-1, epoch=41, batch=19 train cross_entropy <loss>=(0.7069870901388989)
# [08/29/2021 09:12:15 INFO 139876594259776] #quality_metric: host=algo-1, epoch=41, batch=19 train smooth_l1 <loss>=(0.24123422257922333)
# [08/29/2021 09:12:15 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:12:15 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:12:18 INFO 139876594259776] #quality_metric: host=algo-1, epoch=41, validation mAP <score>=(0.8761728015829251)
# [08/29/2021 09:12:18 INFO 139876594259776] Updating the best model with validation-mAP=0.8761728015829251
# [08/29/2021 09:12:18 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:12:18 INFO 139876594259776] #progress_metric: host=algo-1, completed 42.0 % of epochs
# #metrics {"StartTime": 1630228329.9321034, "EndTime": 1630228338.408516, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 41, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 42.0, "count": 1, "min": 42, "max": 42}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:12:23 INFO 139876594259776] #quality_metric: host=algo-1, epoch=42, batch=18 train cross_entropy <loss>=(0.6798711295991295)
# [08/29/2021 09:12:23 INFO 139876594259776] #quality_metric: host=algo-1, epoch=42, batch=18 train smooth_l1 <loss>=(0.25547016306938747)
# [08/29/2021 09:12:23 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:12:24 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:12:26 INFO 139876594259776] #quality_metric: host=algo-1, epoch=42, validation mAP <score>=(0.8533287073306084)
# [08/29/2021 09:12:26 INFO 139876594259776] #progress_metric: host=algo-1, completed 43.0 % of epochs
# #metrics {"StartTime": 1630228338.4088075, "EndTime": 1630228346.2565677, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 42, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 43.0, "count": 1, "min": 43, "max": 43}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:12:31 INFO 139876594259776] #quality_metric: host=algo-1, epoch=43, batch=19 train cross_entropy <loss>=(0.6696642956802589)
# [08/29/2021 09:12:31 INFO 139876594259776] #quality_metric: host=algo-1, epoch=43, batch=19 train smooth_l1 <loss>=(0.23850645184708255)
# [08/29/2021 09:12:31 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:12:31 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:12:34 INFO 139876594259776] #quality_metric: host=algo-1, epoch=43, validation mAP <score>=(0.8828077978701072)
# [08/29/2021 09:12:34 INFO 139876594259776] Updating the best model with validation-mAP=0.8828077978701072
# [08/29/2021 09:12:34 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# ...
#
# [08/29/2021 09:18:40 INFO 139876594259776] #quality_metric: host=algo-1, epoch=89, batch=18 train cross_entropy <loss>=(0.5116091078987812)
# [08/29/2021 09:18:40 INFO 139876594259776] #quality_metric: host=algo-1, epoch=89, batch=18 train smooth_l1 <loss>=(0.18488626257935098)
# [08/29/2021 09:18:40 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:18:41 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:18:42 INFO 139876594259776] #quality_metric: host=algo-1, epoch=89, validation mAP <score>=(0.9613329306103925)
# [08/29/2021 09:18:42 INFO 139876594259776] #progress_metric: host=algo-1, completed 90.0 % of epochs
# #metrics {"StartTime": 1630228714.0867188, "EndTime": 1630228722.925129, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 89, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 90.0, "count": 1, "min": 90, "max": 90}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:18:48 INFO 139876594259776] #quality_metric: host=algo-1, epoch=90, batch=19 train cross_entropy <loss>=(0.4928192100349257)
# [08/29/2021 09:18:48 INFO 139876594259776] #quality_metric: host=algo-1, epoch=90, batch=19 train smooth_l1 <loss>=(0.18380664332035745)
# [08/29/2021 09:18:48 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:18:48 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:18:50 INFO 139876594259776] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.9640525546047553)
# [08/29/2021 09:18:50 INFO 139876594259776] #progress_metric: host=algo-1, completed 91.0 % of epochs
# #metrics {"StartTime": 1630228722.9253755, "EndTime": 1630228730.8509178, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 90, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 91.0, "count": 1, "min": 91, "max": 91}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:18:56 INFO 139876594259776] #quality_metric: host=algo-1, epoch=91, batch=19 train cross_entropy <loss>=(0.5130202228740111)
# [08/29/2021 09:18:56 INFO 139876594259776] #quality_metric: host=algo-1, epoch=91, batch=19 train smooth_l1 <loss>=(0.18893956249043092)
# [08/29/2021 09:18:56 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:18:56 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:18:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.9639374329297503)
# [08/29/2021 09:18:58 INFO 139876594259776] #progress_metric: host=algo-1, completed 92.0 % of epochs
# #metrics {"StartTime": 1630228730.8512788, "EndTime": 1630228738.5332677, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 91, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:04 INFO 139876594259776] #quality_metric: host=algo-1, epoch=92, batch=19 train cross_entropy <loss>=(0.48550604423449867)
# [08/29/2021 09:19:04 INFO 139876594259776] #quality_metric: host=algo-1, epoch=92, batch=19 train smooth_l1 <loss>=(0.17490976882546905)
# [08/29/2021 09:19:04 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:04 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:06 INFO 139876594259776] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.9707851975178988)
# [08/29/2021 09:19:06 INFO 139876594259776] Updating the best model with validation-mAP=0.9707851975178988
# [08/29/2021 09:19:06 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:19:06 INFO 139876594259776] #progress_metric: host=algo-1, completed 93.0 % of epochs
# #metrics {"StartTime": 1630228738.5335045, "EndTime": 1630228746.6562495, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 92, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 93.0, "count": 1, "min": 93, "max": 93}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:12 INFO 139876594259776] #quality_metric: host=algo-1, epoch=93, batch=19 train cross_entropy <loss>=(0.4962478670794638)
# [08/29/2021 09:19:12 INFO 139876594259776] #quality_metric: host=algo-1, epoch=93, batch=19 train smooth_l1 <loss>=(0.17838348835512768)
# [08/29/2021 09:19:12 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:12 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:14 INFO 139876594259776] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.9679982312437284)
# [08/29/2021 09:19:14 INFO 139876594259776] #progress_metric: host=algo-1, completed 94.0 % of epochs
# #metrics {"StartTime": 1630228746.6565127, "EndTime": 1630228754.3854558, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 93, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 94.0, "count": 1, "min": 94, "max": 94}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [08/29/2021 09:19:27 INFO 139876594259776] #quality_metric: host=algo-1, epoch=95, batch=18 train cross_entropy <loss>=(0.4971011033948961)
# [08/29/2021 09:19:27 INFO 139876594259776] #quality_metric: host=algo-1, epoch=95, batch=18 train smooth_l1 <loss>=(0.18639505071954413)
# [08/29/2021 09:19:27 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:27 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:29 INFO 139876594259776] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.9636309026920806)
# [08/29/2021 09:19:29 INFO 139876594259776] #progress_metric: host=algo-1, completed 96.0 % of epochs
# #metrics {"StartTime": 1630228762.154356, "EndTime": 1630228769.7484357, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 95, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 96.0, "count": 1, "min": 96, "max": 96}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:35 INFO 139876594259776] #quality_metric: host=algo-1, epoch=96, batch=19 train cross_entropy <loss>=(0.4715570919868174)
# [08/29/2021 09:19:35 INFO 139876594259776] #quality_metric: host=algo-1, epoch=96, batch=19 train smooth_l1 <loss>=(0.1777660890412185)
# [08/29/2021 09:19:35 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:35 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:37 INFO 139876594259776] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.9694262688552098)
# [08/29/2021 09:19:37 INFO 139876594259776] #progress_metric: host=algo-1, completed 97.0 % of epochs
# #metrics {"StartTime": 1630228769.7487211, "EndTime": 1630228777.5460863, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:43 INFO 139876594259776] #quality_metric: host=algo-1, epoch=97, batch=19 train cross_entropy <loss>=(0.47405439410065775)
# [08/29/2021 09:19:43 INFO 139876594259776] #quality_metric: host=algo-1, epoch=97, batch=19 train smooth_l1 <loss>=(0.1721766788403227)
# [08/29/2021 09:19:43 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:43 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:45 INFO 139876594259776] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.9699143145436935)
# [08/29/2021 09:19:45 INFO 139876594259776] #progress_metric: host=algo-1, completed 98.0 % of epochs
# #metrics {"StartTime": 1630228777.546293, "EndTime": 1630228785.1555846, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:50 INFO 139876594259776] #quality_metric: host=algo-1, epoch=98, batch=19 train cross_entropy <loss>=(0.4901938398835335)
# [08/29/2021 09:19:50 INFO 139876594259776] #quality_metric: host=algo-1, epoch=98, batch=19 train smooth_l1 <loss>=(0.18526951034499237)
# [08/29/2021 09:19:50 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:50 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:19:52 INFO 139876594259776] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.9658854829180259)
# [08/29/2021 09:19:52 INFO 139876594259776] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1630228785.155811, "EndTime": 1630228792.8078492, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:19:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=99, batch=19 train cross_entropy <loss>=(0.4801536194804873)
# [08/29/2021 09:19:58 INFO 139876594259776] #quality_metric: host=algo-1, epoch=99, batch=19 train smooth_l1 <loss>=(0.1816651481663054)
# [08/29/2021 09:19:58 INFO 139876594259776] Round of batches complete
# [08/29/2021 09:19:58 INFO 139876594259776] Updated the metrics
# [08/29/2021 09:20:00 INFO 139876594259776] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.9707965374654653)
# [08/29/2021 09:20:00 INFO 139876594259776] Updating the best model with validation-mAP=0.9707965374654653
# [08/29/2021 09:20:00 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:20:00 INFO 139876594259776] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1630228792.808116, "EndTime": 1630228800.655216, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/29/2021 09:20:00 WARNING 139876594259776] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/29/2021 09:20:00 INFO 139876594259776] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/29/2021 09:20:00 INFO 139876594259776] Test data is not provided.
# #metrics {"StartTime": 1630227912.4814086, "EndTime": 1630228801.1803694, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "setuptime": {"sum": 8.80885124206543, "count": 1, "min": 8.80885124206543, "max": 8.80885124206543}, "totaltime": {"sum": 888807.6672554016, "count": 1, "min": 888807.6672554016, "max": 888807.6672554016}}}
# 2021-08-29 09:20:40 Uploading - Uploading generated training model
# 2021-08-29 09:20:40 Completed - Training job completed
# Training seconds: 990
# Billable seconds: 990

# %%
no_od_model.logs()
# Out:
# 2021-08-27 11:05:56 Starting - Preparing the instances for training
# 2021-08-27 11:05:56 Downloading - Downloading input data
# 2021-08-27 11:05:56 Training - Training image download completed. Training in progress.
# 2021-08-27 11:05:56 Uploading - Uploading generated training model
# 2021-08-27 11:05:56 Completed - Training job completedDocker entrypoint called with argument(s): train
# [08/27/2021 10:48:08 INFO 139682610313024] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'base_network': 'vgg-16', 'use_pretrained_model': '0', 'num_classes': '', 'mini_batch_size': '32', 'epochs': '30', 'learning_rate': '0.001', 'lr_scheduler_step': '', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '', 'image_shape': '300', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# [08/27/2021 10:48:08 INFO 139682610313024] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'weight_decay': '0.756982', 'num_classes': '10', 'num_training_samples': '1070', 'lr_scheduler_step': '3,6', 'overlap_threshold': '0.5', 'image_shape': '300', 'label_width': '350', 'momentum': '0.983774', 'nms_threshold': '0.45', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'base_network': 'resnet-50', 'use_pretrained_model': '1', 'epochs': '100', 'learning_rate': '0.025004', 'mini_batch_size': '16'}
# [08/27/2021 10:48:08 INFO 139682610313024] Final configuration: {'base_network': 'resnet-50', 'use_pretrained_model': '1', 'num_classes': '10', 'mini_batch_size': '16', 'epochs': '100', 'learning_rate': '0.025004', 'lr_scheduler_step': '3,6', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.983774', 'weight_decay': '0.756982', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '1070', 'image_shape': '300', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# Process 1 is a worker.
# [08/27/2021 10:48:08 INFO 139682610313024] Using default worker.
# [08/27/2021 10:48:08 INFO 139682610313024] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [08/27/2021 10:48:08 INFO 139682610313024] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [08/27/2021 10:48:08 INFO 139682610313024] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [08/27/2021 10:48:08 INFO 139682610313024] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [08/27/2021 10:48:08 INFO 139682610313024] Checkpoint loading and saving are disabled.
# [08/27/2021 10:48:08 INFO 139682610313024] nvidia-smi: took 0.081 seconds to run.
# [08/27/2021 10:48:08 INFO 139682610313024] nvidia-smi identified 1 GPUs.
# [08/27/2021 10:48:08 INFO 139682610313024] Number of GPUs being used: 1
# [08/27/2021 10:48:08 WARNING 139682610313024] Training images are resized to image shape (3, 300, 300)
# [10:48:08] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [10:48:08] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [08/27/2021 10:48:09 WARNING 139682610313024] Validation images are resized to image shape (3, 300, 300)
# [10:48:09] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [10:48:10] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [08/27/2021 10:48:10 INFO 139682610313024] Number of GPUs being used: 1
# [08/27/2021 10:48:10 INFO 139682610313024] Using [gpu(0)] as training context.
# [08/27/2021 10:48:10 INFO 139682610313024] Number of GPUs being used: 1
# [08/27/2021 10:48:10 INFO 139682610313024] Create Store: device
# [08/27/2021 10:48:10 INFO 139682610313024] Using (gpu(0)) as training context.
# [08/27/2021 10:48:11 INFO 139682610313024] Start training from pretrained model 1.
# [10:48:11] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [10:48:11] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [08/27/2021 10:48:11 INFO 139682610313024] Loaded pretrained model parameters.
# [08/27/2021 10:48:20 INFO 139682610313024] Creating a new state instance.
# #metrics {"StartTime": 1630061300.183003, "EndTime": 1630061300.183088, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [10:48:20] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.135.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [08/27/2021 10:48:33 INFO 139682610313024] #quality_metric: host=algo-1, epoch=0, batch=66 train cross_entropy <loss>=(2.6340625476260504)
# [08/27/2021 10:48:33 INFO 139682610313024] #quality_metric: host=algo-1, epoch=0, batch=66 train smooth_l1 <loss>=(0.7998273318417299)
# [08/27/2021 10:48:33 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:48:34 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:48:35 INFO 139682610313024] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.0)
# [08/27/2021 10:48:35 INFO 139682610313024] Updating the best model with validation-mAP=0.0
# [08/27/2021 10:48:35 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:48:35 INFO 139682610313024] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1630061300.1834304, "EndTime": 1630061315.293653, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:48:44 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:48:44 INFO 139682610313024] #quality_metric: host=algo-1, epoch=1, batch=65 train cross_entropy <loss>=(1.4545636492804697)
# [08/27/2021 10:48:44 INFO 139682610313024] #quality_metric: host=algo-1, epoch=1, batch=65 train smooth_l1 <loss>=(0.7161894352478388)
# [08/27/2021 10:48:44 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:48:44 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:48:45 INFO 139682610313024] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.0)
# [08/27/2021 10:48:45 INFO 139682610313024] Updating the best model with validation-mAP=0.0
# [08/27/2021 10:48:45 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:48:45 INFO 139682610313024] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1630061315.2938821, "EndTime": 1630061325.5540574, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:48:54 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:48:54 INFO 139682610313024] #quality_metric: host=algo-1, epoch=2, batch=65 train cross_entropy <loss>=(1.2491159189296288)
# [08/27/2021 10:48:54 INFO 139682610313024] #quality_metric: host=algo-1, epoch=2, batch=65 train smooth_l1 <loss>=(0.6930967262042992)
# [08/27/2021 10:48:54 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:48:54 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:48:55 INFO 139682610313024] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.0)
# [08/27/2021 10:48:55 INFO 139682610313024] Updating the best model with validation-mAP=0.0
# [08/27/2021 10:48:55 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:48:55 INFO 139682610313024] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1630061325.5542963, "EndTime": 1630061335.8320284, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:48:56 INFO 139682610313024] Update[199]: Change learning rate to 2.50040e-03
# [08/27/2021 10:49:04 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:49:04 INFO 139682610313024] #quality_metric: host=algo-1, epoch=3, batch=65 train cross_entropy <loss>=(1.2730581124165559)
# [08/27/2021 10:49:04 INFO 139682610313024] #quality_metric: host=algo-1, epoch=3, batch=65 train smooth_l1 <loss>=(0.7029254446112113)
# [08/27/2021 10:49:04 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:04 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:05 INFO 139682610313024] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.0)
# [08/27/2021 10:49:05 INFO 139682610313024] Updating the best model with validation-mAP=0.0
# [08/27/2021 10:49:06 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:49:06 INFO 139682610313024] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1630061335.8322525, "EndTime": 1630061346.044991, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:49:15 INFO 139682610313024] #quality_metric: host=algo-1, epoch=4, batch=66 train cross_entropy <loss>=(1.2661044963797612)
# [08/27/2021 10:49:15 INFO 139682610313024] #quality_metric: host=algo-1, epoch=4, batch=66 train smooth_l1 <loss>=(0.7018097816745034)
# [08/27/2021 10:49:15 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:15 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:16 INFO 139682610313024] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(1.8448210339115002e-07)
# [08/27/2021 10:49:16 INFO 139682610313024] Updating the best model with validation-mAP=1.8448210339115002e-07
# [08/27/2021 10:49:17 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:49:17 INFO 139682610313024] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1630061346.0452366, "EndTime": 1630061357.0912387, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:49:25 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:49:25 INFO 139682610313024] #quality_metric: host=algo-1, epoch=5, batch=65 train cross_entropy <loss>=(1.2200297985515616)
# [08/27/2021 10:49:25 INFO 139682610313024] #quality_metric: host=algo-1, epoch=5, batch=65 train smooth_l1 <loss>=(0.6802278395419836)
# [08/27/2021 10:49:25 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:25 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:27 INFO 139682610313024] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.00015217497708128126)
# [08/27/2021 10:49:27 INFO 139682610313024] Updating the best model with validation-mAP=0.00015217497708128126
# [08/27/2021 10:49:27 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:49:27 INFO 139682610313024] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1630061357.0914583, "EndTime": 1630061367.1430287, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:49:27 INFO 139682610313024] Update[397]: Change learning rate to 2.50040e-04
# [08/27/2021 10:49:35 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:49:35 INFO 139682610313024] #quality_metric: host=algo-1, epoch=6, batch=65 train cross_entropy <loss>=(1.2060487693006343)
# [08/27/2021 10:49:35 INFO 139682610313024] #quality_metric: host=algo-1, epoch=6, batch=65 train smooth_l1 <loss>=(0.6881611504338004)
# [08/27/2021 10:49:35 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:36 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:36 INFO 139682610313024] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(9.090489596363736e-05)
# [08/27/2021 10:49:36 INFO 139682610313024] #progress_metric: host=algo-1, completed 7.0 % of epochs
# #metrics {"StartTime": 1630061367.143444, "EndTime": 1630061376.960886, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:49:45 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:49:45 INFO 139682610313024] #quality_metric: host=algo-1, epoch=7, batch=65 train cross_entropy <loss>=(1.2028170443595725)
# [08/27/2021 10:49:45 INFO 139682610313024] #quality_metric: host=algo-1, epoch=7, batch=65 train smooth_l1 <loss>=(0.6897073208551524)
# [08/27/2021 10:49:45 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:45 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:46 INFO 139682610313024] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.00013143552135265723)
# [08/27/2021 10:49:46 INFO 139682610313024] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1630061376.9610677, "EndTime": 1630061386.7375467, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:49:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=8, batch=66 train cross_entropy <loss>=(1.192562596837423)
# [08/27/2021 10:49:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=8, batch=66 train smooth_l1 <loss>=(0.6928233789855631)
# [08/27/2021 10:49:56 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:49:56 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:49:57 INFO 139682610313024] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(8.975352546816973e-05)
# [08/27/2021 10:49:57 INFO 139682610313024] #progress_metric: host=algo-1, completed 9.0 % of epochs
# #metrics {"StartTime": 1630061386.7377603, "EndTime": 1630061397.3795304, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:06 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:50:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=9, batch=65 train cross_entropy <loss>=(1.188625325793626)
# [08/27/2021 10:50:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=9, batch=65 train smooth_l1 <loss>=(0.7005091378983054)
# [08/27/2021 10:50:06 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:06 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:07 INFO 139682610313024] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(4.6082601174011895e-05)
# [08/27/2021 10:50:07 INFO 139682610313024] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1630061397.3797133, "EndTime": 1630061407.4491434, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:16 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:50:16 INFO 139682610313024] #quality_metric: host=algo-1, epoch=10, batch=65 train cross_entropy <loss>=(1.1872206657501994)
# [08/27/2021 10:50:16 INFO 139682610313024] #quality_metric: host=algo-1, epoch=10, batch=65 train smooth_l1 <loss>=(0.6759934934190135)
# [08/27/2021 10:50:16 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:16 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:17 INFO 139682610313024] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(7.291338052812841e-05)
# [08/27/2021 10:50:17 INFO 139682610313024] #progress_metric: host=algo-1, completed 11.0 % of epochs
# #metrics {"StartTime": 1630061407.449353, "EndTime": 1630061417.3893394, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:26 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:50:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=11, batch=65 train cross_entropy <loss>=(1.1863567017746182)
# [08/27/2021 10:50:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=11, batch=65 train smooth_l1 <loss>=(0.6793212769640393)
# [08/27/2021 10:50:26 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:26 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:27 INFO 139682610313024] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(7.048572978343717e-05)
# [08/27/2021 10:50:27 INFO 139682610313024] #progress_metric: host=algo-1, completed 12.0 % of epochs
# #metrics {"StartTime": 1630061417.3895535, "EndTime": 1630061427.230937, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:36 INFO 139682610313024] #quality_metric: host=algo-1, epoch=12, batch=66 train cross_entropy <loss>=(1.1883317165443767)
# [08/27/2021 10:50:36 INFO 139682610313024] #quality_metric: host=algo-1, epoch=12, batch=66 train smooth_l1 <loss>=(0.6882453507578145)
# [08/27/2021 10:50:36 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:36 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:37 INFO 139682610313024] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(8.007499916185806e-05)
# [08/27/2021 10:50:37 INFO 139682610313024] #progress_metric: host=algo-1, completed 13.0 % of epochs
# #metrics {"StartTime": 1630061427.2311227, "EndTime": 1630061437.7794063, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:46 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:50:46 INFO 139682610313024] #quality_metric: host=algo-1, epoch=13, batch=65 train cross_entropy <loss>=(1.1907379196483054)
# [08/27/2021 10:50:46 INFO 139682610313024] #quality_metric: host=algo-1, epoch=13, batch=65 train smooth_l1 <loss>=(0.6890987576220198)
# [08/27/2021 10:50:46 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:46 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:47 INFO 139682610313024] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(5.619788761112412e-05)
# [08/27/2021 10:50:47 INFO 139682610313024] #progress_metric: host=algo-1, completed 14.0 % of epochs
# #metrics {"StartTime": 1630061437.7796197, "EndTime": 1630061447.6692395, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:50:56 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:50:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=14, batch=65 train cross_entropy <loss>=(1.179212965630105)
# [08/27/2021 10:50:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=14, batch=65 train smooth_l1 <loss>=(0.6961340202921886)
# [08/27/2021 10:50:56 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:50:56 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:50:57 INFO 139682610313024] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(9.768986291410183e-05)
# [08/27/2021 10:50:57 INFO 139682610313024] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1630061447.6696105, "EndTime": 1630061457.3862305, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:06 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:51:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=15, batch=65 train cross_entropy <loss>=(1.1848529555776097)
# [08/27/2021 10:51:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=15, batch=65 train smooth_l1 <loss>=(0.6778883085594521)
# [08/27/2021 10:51:06 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:06 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:07 INFO 139682610313024] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.0007563730739290057)
# [08/27/2021 10:51:07 INFO 139682610313024] Updating the best model with validation-mAP=0.0007563730739290057
# [08/27/2021 10:51:07 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 10:51:07 INFO 139682610313024] #progress_metric: host=algo-1, completed 16.0 % of epochs
# #metrics {"StartTime": 1630061457.3864255, "EndTime": 1630061467.4610524, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 15, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:17 INFO 139682610313024] #quality_metric: host=algo-1, epoch=16, batch=66 train cross_entropy <loss>=(1.1797697196784964)
# [08/27/2021 10:51:17 INFO 139682610313024] #quality_metric: host=algo-1, epoch=16, batch=66 train smooth_l1 <loss>=(0.6880990108811712)
# [08/27/2021 10:51:17 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:17 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:18 INFO 139682610313024] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(5.139608892375379e-05)
# [08/27/2021 10:51:18 INFO 139682610313024] #progress_metric: host=algo-1, completed 17.0 % of epochs
# #metrics {"StartTime": 1630061467.4612896, "EndTime": 1630061478.082911, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 16, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:26 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:51:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=17, batch=65 train cross_entropy <loss>=(1.1798743184702323)
# [08/27/2021 10:51:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=17, batch=65 train smooth_l1 <loss>=(0.6968276118651848)
# [08/27/2021 10:51:26 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:27 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:27 INFO 139682610313024] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(7.035942953631738e-05)
# [08/27/2021 10:51:27 INFO 139682610313024] #progress_metric: host=algo-1, completed 18.0 % of epochs
# #metrics {"StartTime": 1630061478.0831556, "EndTime": 1630061487.8423707, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 17, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:36 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:51:36 INFO 139682610313024] #quality_metric: host=algo-1, epoch=18, batch=65 train cross_entropy <loss>=(1.1800025090643005)
# [08/27/2021 10:51:36 INFO 139682610313024] #quality_metric: host=algo-1, epoch=18, batch=65 train smooth_l1 <loss>=(0.6791754460507037)
# [08/27/2021 10:51:36 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:36 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:37 INFO 139682610313024] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(7.019133737989802e-05)
# [08/27/2021 10:51:37 INFO 139682610313024] #progress_metric: host=algo-1, completed 19.0 % of epochs
# #metrics {"StartTime": 1630061487.8425438, "EndTime": 1630061497.5587459, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 18, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:46 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:51:46 INFO 139682610313024] #quality_metric: host=algo-1, epoch=19, batch=65 train cross_entropy <loss>=(1.1838993159448392)
# [08/27/2021 10:51:46 INFO 139682610313024] #quality_metric: host=algo-1, epoch=19, batch=65 train smooth_l1 <loss>=(0.6865186670079637)
# [08/27/2021 10:51:46 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:46 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:47 INFO 139682610313024] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(6.626825139819474e-05)
# [08/27/2021 10:51:47 INFO 139682610313024] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1630061497.559033, "EndTime": 1630061507.232301, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:51:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=20, batch=66 train cross_entropy <loss>=(1.1751223435947367)
# [08/27/2021 10:51:56 INFO 139682610313024] #quality_metric: host=algo-1, epoch=20, batch=66 train smooth_l1 <loss>=(0.6778088130892534)
# [08/27/2021 10:51:56 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:51:56 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:51:57 INFO 139682610313024] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(7.973732203892562e-05)
# [08/27/2021 10:51:57 INFO 139682610313024] #progress_metric: host=algo-1, completed 21.0 % of epochs
# #metrics {"StartTime": 1630061507.2324646, "EndTime": 1630061517.8599539, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:52:06 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:52:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=21, batch=65 train cross_entropy <loss>=(1.1794825687505817)
# [08/27/2021 10:52:06 INFO 139682610313024] #quality_metric: host=algo-1, epoch=21, batch=65 train smooth_l1 <loss>=(0.6933689739510747)
# [08/27/2021 10:52:06 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:52:06 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:52:07 INFO 139682610313024] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.00010166664964130643)
# [08/27/2021 10:52:07 INFO 139682610313024] #progress_metric: host=algo-1, completed 22.0 % of epochs
# #metrics {"StartTime": 1630061517.860245, "EndTime": 1630061527.985235, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 21, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:52:16 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:52:16 INFO 139682610313024] #quality_metric: host=algo-1, epoch=22, batch=65 train cross_entropy <loss>=(1.1780857210573943)
# [08/27/2021 10:52:16 INFO 139682610313024] #quality_metric: host=algo-1, epoch=22, batch=65 train smooth_l1 <loss>=(0.6774716388169906)
# [08/27/2021 10:52:16 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:52:16 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:52:17 INFO 139682610313024] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(6.41402721948232e-05)
# [08/27/2021 10:52:17 INFO 139682610313024] #progress_metric: host=algo-1, completed 23.0 % of epochs
# #metrics {"StartTime": 1630061527.98545, "EndTime": 1630061537.901572, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 22, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 10:52:26 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 10:52:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=23, batch=65 train cross_entropy <loss>=(1.184659379193572)
# [08/27/2021 10:52:26 INFO 139682610313024] #quality_metric: host=algo-1, epoch=23, batch=65 train smooth_l1 <loss>=(0.6786537902209223)
# [08/27/2021 10:52:26 INFO 139682610313024] Round of batches complete
# [08/27/2021 10:52:26 INFO 139682610313024] Updated the metrics
# [08/27/2021 10:52:27 INFO 139682610313024] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(7.580884024598563e-05)
# [08/27/2021 10:52:27 INFO 139682610313024] #progress_metric: host=algo-1, completed 24.0 % of epochs
# ...
# [08/27/2021 11:03:49 INFO 139682610313024] #quality_metric: host=algo-1, epoch=91, batch=65 train cross_entropy <loss>=(1.1523734841833642)
# [08/27/2021 11:03:49 INFO 139682610313024] #quality_metric: host=algo-1, epoch=91, batch=65 train smooth_l1 <loss>=(0.6862563972668994)
# [08/27/2021 11:03:49 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:03:50 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:03:51 INFO 139682610313024] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(6.892904785227717e-05)
# [08/27/2021 11:03:51 INFO 139682610313024] #progress_metric: host=algo-1, completed 92.0 % of epochs
# #metrics {"StartTime": 1630062221.2201962, "EndTime": 1630062231.1967502, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 91, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:00 INFO 139682610313024] #quality_metric: host=algo-1, epoch=92, batch=66 train cross_entropy <loss>=(1.1638950519830409)
# [08/27/2021 11:04:00 INFO 139682610313024] #quality_metric: host=algo-1, epoch=92, batch=66 train smooth_l1 <loss>=(0.6689647035195794)
# [08/27/2021 11:04:00 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:00 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:01 INFO 139682610313024] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(7.32806936808471e-05)
# [08/27/2021 11:04:01 INFO 139682610313024] #progress_metric: host=algo-1, completed 93.0 % of epochs
# #metrics {"StartTime": 1630062231.1968975, "EndTime": 1630062241.8032768, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 92, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 93.0, "count": 1, "min": 93, "max": 93}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:10 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:04:10 INFO 139682610313024] #quality_metric: host=algo-1, epoch=93, batch=65 train cross_entropy <loss>=(1.1536274812614915)
# [08/27/2021 11:04:10 INFO 139682610313024] #quality_metric: host=algo-1, epoch=93, batch=65 train smooth_l1 <loss>=(0.6891214606896243)
# [08/27/2021 11:04:10 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:11 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:12 INFO 139682610313024] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(7.604912152361999e-05)
# [08/27/2021 11:04:12 INFO 139682610313024] #progress_metric: host=algo-1, completed 94.0 % of epochs
# #metrics {"StartTime": 1630062241.8035183, "EndTime": 1630062252.0195928, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 93, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 94.0, "count": 1, "min": 94, "max": 94}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:20 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:04:20 INFO 139682610313024] #quality_metric: host=algo-1, epoch=94, batch=65 train cross_entropy <loss>=(1.1554945972417836)
# [08/27/2021 11:04:20 INFO 139682610313024] #quality_metric: host=algo-1, epoch=94, batch=65 train smooth_l1 <loss>=(0.6773989554278829)
# [08/27/2021 11:04:20 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:20 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:21 INFO 139682610313024] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.00040593508917474187)
# [08/27/2021 11:04:21 INFO 139682610313024] #progress_metric: host=algo-1, completed 95.0 % of epochs
# #metrics {"StartTime": 1630062252.0197692, "EndTime": 1630062261.788408, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 94, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 95.0, "count": 1, "min": 95, "max": 95}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:30 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:04:30 INFO 139682610313024] #quality_metric: host=algo-1, epoch=95, batch=65 train cross_entropy <loss>=(1.1493631398902748)
# [08/27/2021 11:04:30 INFO 139682610313024] #quality_metric: host=algo-1, epoch=95, batch=65 train smooth_l1 <loss>=(0.6815730275393487)
# [08/27/2021 11:04:30 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:30 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:31 INFO 139682610313024] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.0004299429994692089)
# [08/27/2021 11:04:31 INFO 139682610313024] #progress_metric: host=algo-1, completed 96.0 % of epochs
# #metrics {"StartTime": 1630062261.7886133, "EndTime": 1630062271.6410942, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 95, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 96.0, "count": 1, "min": 96, "max": 96}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:41 INFO 139682610313024] #quality_metric: host=algo-1, epoch=96, batch=66 train cross_entropy <loss>=(1.1561348313059887)
# [08/27/2021 11:04:41 INFO 139682610313024] #quality_metric: host=algo-1, epoch=96, batch=66 train smooth_l1 <loss>=(0.6838763993545618)
# [08/27/2021 11:04:41 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:41 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:42 INFO 139682610313024] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(8.328910343570604e-05)
# [08/27/2021 11:04:42 INFO 139682610313024] #progress_metric: host=algo-1, completed 97.0 % of epochs
# #metrics {"StartTime": 1630062271.641257, "EndTime": 1630062282.3858552, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:04:51 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:04:51 INFO 139682610313024] #quality_metric: host=algo-1, epoch=97, batch=65 train cross_entropy <loss>=(1.1554971033867483)
# [08/27/2021 11:04:51 INFO 139682610313024] #quality_metric: host=algo-1, epoch=97, batch=65 train smooth_l1 <loss>=(0.692297927736735)
# [08/27/2021 11:04:51 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:04:51 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:04:52 INFO 139682610313024] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.001025510418788718)
# [08/27/2021 11:04:52 INFO 139682610313024] Updating the best model with validation-mAP=0.001025510418788718
# [08/27/2021 11:04:52 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 11:04:52 INFO 139682610313024] #progress_metric: host=algo-1, completed 98.0 % of epochs
# #metrics {"StartTime": 1630062282.386175, "EndTime": 1630062292.5076523, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:05:01 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:05:01 INFO 139682610313024] #quality_metric: host=algo-1, epoch=98, batch=65 train cross_entropy <loss>=(1.1520135072501296)
# [08/27/2021 11:05:01 INFO 139682610313024] #quality_metric: host=algo-1, epoch=98, batch=65 train smooth_l1 <loss>=(0.6802824343921252)
# [08/27/2021 11:05:01 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:05:01 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:05:02 INFO 139682610313024] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(6.141627253284683e-05)
# [08/27/2021 11:05:02 INFO 139682610313024] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1630062292.5079076, "EndTime": 1630062302.6729088, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:05:11 WARNING 139682610313024] The number of batches processed (65) is less than expected (at least 66). This may happen when some images or annotations are invalid and cannot be parsed or when the value of hyperparameter num_training_samples is set incorrectly. Please check the hyperparameters and check the dataset to ensure it follows the format in the documentation.
# [08/27/2021 11:05:11 INFO 139682610313024] #quality_metric: host=algo-1, epoch=99, batch=65 train cross_entropy <loss>=(1.1672410263239674)
# [08/27/2021 11:05:11 INFO 139682610313024] #quality_metric: host=algo-1, epoch=99, batch=65 train smooth_l1 <loss>=(0.6830271737199421)
# [08/27/2021 11:05:11 INFO 139682610313024] Round of batches complete
# [08/27/2021 11:05:11 INFO 139682610313024] Updated the metrics
# [08/27/2021 11:05:12 INFO 139682610313024] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(7.461212202176228e-05)
# [08/27/2021 11:05:12 INFO 139682610313024] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1630062302.6731296, "EndTime": 1630062312.5683424, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [08/27/2021 11:05:12 WARNING 139682610313024] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/27/2021 11:05:12 INFO 139682610313024] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [08/27/2021 11:05:12 INFO 139682610313024] Test data is not provided.
# #metrics {"StartTime": 1630061288.559879, "EndTime": 1630062313.3195534, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "setuptime": {"sum": 7.333993911743164, "count": 1, "min": 7.333993911743164, "max": 7.333993911743164}, "totaltime": {"sum": 1024861.1869812012, "count": 1, "min": 1024861.1869812012, "max": 1024861.1869812012}}}
#
# Training seconds: 1113
# Billable seconds: 1113

# %% [markdown]
# ### Visualise Training logs

# %%
import boto3
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

client = boto3.client("logs")
BASE_LOG_NAME = "/aws/sagemaker/TrainingJobs"


def plot_object_detection_log(model, title):
    logs = client.describe_log_streams(
        logGroupName=BASE_LOG_NAME, logStreamNamePrefix=model._current_job_name
    )
    cw_log = client.get_log_events(
        logGroupName=BASE_LOG_NAME, logStreamName=logs["logStreams"][0]["logStreamName"]
    )

    mAP_accs = []
    for e in cw_log["events"]:
        msg = e["message"]
        if "validation mAP <score>=" in msg:
            num_start = msg.find("(")
            num_end = msg.find(")")
            mAP = msg[num_start + 1 : num_end]
            mAP_accs.append(float(mAP))

    print(title)
    print("Maximum mAP: %f " % max(mAP_accs))

    fig, ax = plt.subplots()
    plt.xlabel("Epochs")
    plt.ylabel("Mean Avg Precision (mAP)")
    (val_plot,) = ax.plot(range(len(mAP_accs)), mAP_accs, label="mAP")
    plt.legend(handles=[val_plot])
    ax.yaxis.set_ticks(np.arange(0.0, 1.05, 0.1))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%0.2f"))
    plt.show()

# %%
plot_object_detection_log(no_od_model, "mAP tracking for job: " + no_od_model._current_job_name)
# Out:
# mAP tracking for job: object-detection-2021-08-29-09-01-26-558
# Maximum mAP: 0.970797

# %%
import boto3
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

client = boto3.client("logs")
BASE_LOG_NAME = "/aws/sagemaker/TrainingJobs"


def plot_object_detection_log(model, title):
    logs = client.describe_log_streams(
        logGroupName=BASE_LOG_NAME, logStreamNamePrefix=model._current_job_name
    )
    cw_log = client.get_log_events(
        logGroupName=BASE_LOG_NAME, logStreamName=logs["logStreams"][0]["logStreamName"]
    )

    mAP_accs = []
    for e in cw_log["events"]:
        msg = e["message"]
        if "train smooth_l1 <loss>=" in msg:
            num_start = msg.find("(")
            num_end = msg.find(")")
            mAP = msg[num_start + 1 : num_end]
            mAP_accs.append(float(mAP))

    print(title)
    print("Mnimum loss: %f " % min(mAP_accs))

    fig, ax = plt.subplots()
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    (val_plot,) = ax.plot(range(len(mAP_accs)), mAP_accs, label="Loss")
    plt.legend(handles=[val_plot])
    ax.yaxis.set_ticks(np.arange(0.0, 1.05, 0.1))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%0.2f"))
    plt.show()

# %%
plot_object_detection_log(no_od_model, "Loss tracking for job: " + no_od_model._current_job_name)
# Out:
# Loss tracking for job: object-detection-2021-08-29-09-01-26-558
# Mnimum loss: 0.172177
